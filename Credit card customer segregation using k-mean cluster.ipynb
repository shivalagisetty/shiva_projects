# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, normalize
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

# %% [markdown]
# # Loading the dataset

# %%
CC_df = pd.read_csv(r"C:\Users\Shiva\Documents\MY personal\Learning Material\coursera\Customer Grouping (k-cluster)\Marketing_data.csv")
CC_df.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %%
CC_df.drop("CUST_ID", axis =1,inplace = True)

# %%
CC_df.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# ...

# %%
sns.heatmap(CC_df.isnull(), yticklabels = False, cbar = False, cmap="Blues") #searching for null values

# %%
CC_df.isnull().sum()
# Out:
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
CC_df.MINIMUM_PAYMENTS.fillna(CC_df.MINIMUM_PAYMENTS.mean(), inplace = True)
CC_df.CREDIT_LIMIT.fillna(CC_df.CREDIT_LIMIT.mean(), inplace = True) #filling null values with meean

# %%
CC_df.duplicated().sum()
# Out:
# 0

# %%
plt.figure(figsize=(10,50))
for i in range(len(CC_df.columns)):
  plt.subplot(17, 1, i+1)
  sns.distplot(CC_df[CC_df.columns[i]], kde=0)
  plt.title(CC_df.columns[i])

plt.tight_layout()

# %%
f, ax = plt.subplots(figsize=(12,8))
sns.heatmap(CC_df.corr(), annot = True) #visualisinfg the corealations

# %%
scaler = StandardScaler()
CC_df_scaled = scaler.fit_transform(CC_df) #standardisation

# %%
CC_df_scaled.shape
# Out:
# (8950, 17)

# %%
CC_df_scaled
# Out:
# array([[-0.73198937, -0.24943448, -0.42489974, ..., -0.31096755,
#         -0.52555097,  0.36067954],
#        [ 0.78696085,  0.13432467, -0.46955188, ...,  0.08931021,
#          0.2342269 ,  0.36067954],
#        [ 0.44713513,  0.51808382, -0.10766823, ..., -0.10166318,
#         -0.52555097,  0.36067954],
#        ...,
#        [-0.7403981 , -0.18547673, -0.40196519, ..., -0.33546549,
#          0.32919999, -4.12276757],
#        [-0.74517423, -0.18547673, -0.46955188, ..., -0.34690648,
#          0.32919999, -4.12276757],
#        [-0.57257511, -0.88903307,  0.04214581, ..., -0.33294642,
#         -0.52555097, -4.12276757]])

# %%
score_1 = []
#range_values = 
for i in range(1,20):
    kmeans = KMeans(n_clusters= i)
    kmeans.fit(CC_df_scaled)
    score_1.append(kmeans.inertia_)
    
plt.plot(score_1, 'bx-' )          #using elbow method for finding proper no. of cluster value

# %%
kmeans = KMeans(8)
kmeans.fit(CC_df_scaled)
labels = kmeans.labels_

# %%
cluster_centers = pd.DataFrame(data = kmeans.cluster_centers_, columns = [CC_df.columns])
cluster_centers
# Out:
#     BALANCE BALANCE_FREQUENCY  PURCHASES ONEOFF_PURCHASES  \
# 0 -0.336050         -0.347078  -0.289267        -0.215966
# 1 -0.162873          0.392754   0.473201         0.617653
# 2 -0.366639          0.333155  -0.038243        -0.244205
# 3 -0.701163         -2.144787  -0.311233        -0.235823
# 4  0.934901          0.467049   2.252953         1.707412
# 5  0.017656          0.403788  -0.361696        -0.247111
# 6  1.691648          0.395578  -0.218284        -0.156544
# 7  1.923051          0.337717  11.212042        10.600367
#
#   INSTALLMENTS_PURCHASES CASH_ADVANCE PURCHASES_FREQUENCY  \
# 0              -0.286835     0.068284           -0.203078
# 1              -0.016010    -0.333808            0.944809
# 2               0.358036    -0.363598            0.991214
# 3              -0.302542    -0.319756           -0.557150
# 4               2.190297    -0.192704            1.160751
# 5              -0.401127    -0.090434           -0.865566
# ...

# %%
cluster_centers = scaler.inverse_transform(cluster_centers)
cluster_centers = pd.DataFrame(data = cluster_centers, columns = [CC_df.columns])
cluster_centers
# Out:
#        BALANCE BALANCE_FREQUENCY     PURCHASES ONEOFF_PURCHASES  \
# 0   865.015978          0.795051    385.181720       233.977974
# 1  1225.469199          0.970310   2014.205154      1617.614991
# 2   801.347031          0.956192    921.498712       187.107663
# 3   105.063837          0.369191    338.250830       201.019898
# 4  3510.393168          0.987910   5816.674519      3426.390962
# 5  1601.223398          0.972924    230.435818       182.284502
# 6  5085.498117          0.970980    536.838447       332.605956
# 7  5567.142164          0.957273  24957.905000     18186.875667
#
#   INSTALLMENTS_PURCHASES CASH_ADVANCE PURCHASES_FREQUENCY  \
# 0             151.686061  1122.064941            0.408846
# 1             396.590163   278.861158            0.869548
# 2             734.835246   216.389570            0.888173
# 3             137.482244   308.328143            0.266740
# 4            2391.725865   574.762188            0.956216
# ...

# %%
y_kmeans = kmeans.fit_predict(CC_df_scaled)
y_kmeans
# Out:
# array([1, 3, 0, ..., 6, 6, 6])

# %%
CC_df_cluster = pd.concat([CC_df, pd.DataFrame({'cluster':labels})], axis = 1)
CC_df_cluster.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# ...

# %%
for i in CC_df.columns:
  plt.figure(figsize = (35, 5))
  for j in range(7):
    plt.subplot(1,7,j+1)
    cluster = CC_df_cluster[CC_df_cluster['cluster'] == j]
    cluster[i].hist(bins = 20)
    plt.title('{}    \nCluster {} '.format(i,j))
  
  plt.show()

# %% [markdown]
# # PCA algorithm (used for dimension reductionality)

# %%
pca = PCA(n_components = 2)
principal_comp = pca.fit_transform(CC_df_scaled)

# %%
pca_df = pd.DataFrame(data = principal_comp, columns =['pca1','pca2'])
pca_df.head()
# Out:
#        pca1      pca2
# 0 -1.682221 -1.076455
# 1 -1.138296  2.506481
# 2  0.969682 -0.383527
# 3 -0.873628  0.043153
# 4 -1.599434 -0.688581

# %%
pca_df = pd.concat([pca_df,pd.DataFrame({'cluster':labels})], axis = 1)
pca_df.head()
# Out:
#        pca1      pca2  cluster
# 0 -1.682221 -1.076455        5
# 1 -1.138296  2.506481        6
# 2  0.969682 -0.383527        1
# 3 -0.873628  0.043153        5
# 4 -1.599434 -0.688581        5

# %%
plt.figure(figsize=(10,10))
ax = sns.scatterplot(x="pca1", y="pca2", hue = "cluster", data = pca_df, palette =['red','green','blue','pink','yellow','gray','purple','black'])
plt.show() #visualisation of clusters

# %% [markdown]
# # THE END #
